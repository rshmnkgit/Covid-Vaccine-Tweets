# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the csv file and display the data
tweet_data = pd.read_csv("resources/covidvaccine.csv")
print(len(tweet_data))
tweet_data.head()
# Out:
# 156496
#                  user_name              user_location  \
# 0                 MyNewsNE                      Assam
# 1            Shubham Gupta                        NaN
# 2  Journal of Infectiology                        NaN
# 3                     Zane                        NaN
# 4       Ann-Maree O’Connor  Adelaide, South Australia
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3                                  Fresher than you.  18-09-2019 11:01
# 4  Retired university administrator. Melburnian b...  24-01-2013 14:53
#
#    user_followers user_friends user_favourites user_verified  \
# 0            64.0         11.0           110.0         False
# 1             1.0         17.0             0.0         False
# 2           143.0        566.0             8.0         False
# 3            29.0         25.0           620.0         False
# 4            83.0        497.0         10737.0         False
#
#                date                                               text  \
# 0  18-08-2020 12:55  Australia to Manufacture Covid-19 Vaccine and ...
# 1  18-08-2020 12:55  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  18-08-2020 12:46  Deaths due to COVID-19 in Affected Countries\n...
# 3  18-08-2020 12:45  @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4  18-08-2020 12:45  @michellegrattan @ConversationEDU This is what...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 2                                                NaN      Twitter Web App
# 3                                                NaN  Twitter for Android
# 4                                                NaN      Twitter Web App
#
#   is_retweet
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
# Display the data information
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156496 entries, 0 to 156495
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         156492 non-null  object
#  1   user_location     124634 non-null  object
#  2   user_description  147600 non-null  object
#  3   user_created      156492 non-null  object
#  4   user_followers    156491 non-null  float64
#  5   user_friends      156491 non-null  object
#  6   user_favourites   156491 non-null  object
#  7   user_verified     156491 non-null  object
#  8   date              156490 non-null  object
#  9   text              156491 non-null  object
#  10  hashtags          106430 non-null  object
#  11  source            156348 non-null  object
#  12  is_retweet        156486 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 15.5+ MB

# %%
tweet_data.dtypes
# Out:
# user_name            object
# user_location        object
# user_description     object
# user_created         object
# user_followers      float64
# user_friends         object
# user_favourites      object
# user_verified        object
# date                 object
# text                 object
# hashtags             object
# source               object
# is_retweet           object
# dtype: object

# %%
# Filter the records with null user name 
tweet_data[tweet_data['user_name'].isnull()]
# Out:
#        user_name user_location  \
# 51425        NaN           NaN
# 121242       NaN           NaN
# 140102       NaN           NaN
# 151183       NaN           NaN
#
#                                          user_description  \
# 51425   @PelosiLovesDJT's account is temporarily unava...
# 121242  @farrahraja's account has been withheld in Ind...
# 140102  @EngrMuhammadQa9's account has been withheld i...
# 151183  @furqanraja1122's account has been withheld in...
#
#                user_created  user_followers user_friends user_favourites  \
# 51425   2021-01-10 04:52:08            90.0           36              37
# 121242  2015-08-22 22:43:18          4989.0         1482          145584
# 140102  2020-11-03 09:16:01             6.0           79            2528
# 151183  2015-10-06 11:25:25          2224.0         2816            3591
#
#        user_verified                 date  \
# 51425          False  2021-01-12 04:17:00
# 121242         False  2021-02-06 11:41:46
# 140102         False  2021-02-24 12:41:52
# 151183         False  2021-02-28 14:36:18
#
#                                                      text hashtags  \
# 51425   @PelosiLovesDJT's account is temporarily unava...      NaN
# 121242  @farrahraja's account has been withheld in Ind...      NaN
# 140102  @EngrMuhammadQa9's account has been withheld i...      NaN
# 151183  @furqanraja1122's account has been withheld in...      NaN
#
#                      source is_retweet
# 51425   Twitter for Android      False
# 121242  Twitter for Android      False
# 140102  Twitter for Android      False
# 151183      Twitter Web App      False

# %% [markdown]
# The description shows that the user accounts have been withheld and no tweets are available in these records. So these records can be deleted

# %%
# Delete records with null user name
tweet_data.drop(tweet_data[tweet_data['user_name'].isnull()].index, inplace=True)

# %%
# Check if the null usernames are deleted
tweet_data[tweet_data['user_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet]
# Index: []

# %%
tweet_data[tweet_data['user_location'].isnull()]
# Out:
#                                 user_name user_location  \
# 1                           Shubham Gupta           NaN
# 2                 Journal of Infectiology           NaN
# 3                                    Zane           NaN
# 5            Raunak Scherbatsky DankWorth           NaN
# 14                    Live sport is back!           NaN
# ...                                   ...           ...
# 156481  Dr. Akbar Niazi Teaching Hospital           NaN
# 156486  Dr. Akbar Niazi Teaching Hospital           NaN
# 156490  Dr. Akbar Niazi Teaching Hospital           NaN
# 156492  Dr. Akbar Niazi Teaching Hospital           NaN
# 156494                             Sophia           NaN
#
#                                          user_description  \
# 1       I will tell about all experiences of my life f...
# 2       Journal of Infectiology (ISSN 2689-9981) is ac...
# 3                                       Fresher than you.
# 5       Neuro surgeon + Diagnostician.👨‍⚕️\na good phy...
# 14                           Sport is the elixir of life!
# ...                                                   ...
# 156481  Dr. Akbar Niazi Teaching Hospital (ANTH) is a ...
# 156486  Dr. Akbar Niazi Teaching Hospital (ANTH) is a ...
# 156490  Dr. Akbar Niazi Teaching Hospital (ANTH) is a ...
# 156492  Dr. Akbar Niazi Teaching Hospital (ANTH) is a ...
# 156494  'One day the war will end and I will resume my...
#
#                user_created  user_followers user_friends user_favourites  \
# 1          14-08-2020 16:42             1.0         17.0             0.0
# 2          14-12-2017 07:07           143.0        566.0             8.0
# 3          18-09-2019 11:01            29.0         25.0           620.0
# 5          03-08-2020 13:39             3.0         27.0           918.0
# 14         31-03-2009 08:14           147.0        351.0           482.0
# ...                     ...             ...          ...             ...
# 156481  2019-03-24 07:32:27            83.0            9               1
# 156486  2019-03-24 07:32:27            83.0            9               1
# 156490  2019-03-24 07:32:27            83.0            9               1
# 156492  2019-03-24 07:32:27            83.0            9               1
# 156494  2010-06-02 02:04:42          6688.0         2744           64605
#
#        user_verified                 date  \
# 1              False     18-08-2020 12:55
# 2              False     18-08-2020 12:46
# 3              False     18-08-2020 12:45
# 5              False     18-08-2020 12:44
# 14             False     18-08-2020 10:39
# ...              ...                  ...
# 156481         False  2021-03-04 12:20:07
# 156486         False  2021-03-04 12:19:45
# 156490         False  2021-03-04 12:19:15
# 156492         False  2021-03-04 12:18:55
# 156494         False  2021-03-04 12:18:39
#
#                                                      text  \
# 1       #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2       Deaths due to COVID-19 in Affected Countries\n...
# 3       @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 5       The Multi-system Inflammatory Syndrome-Childre...
# 14      The whole narrative on the #CovidVaccine has g...
# ...                                                   ...
# 156481  A sad incident took place in #Japan🇯🇵. Accordi...
# 156486  Necessary efforts have been made to raise mass...
# 156490  Parliamentary Health Secretary Dr. Nausheen Ha...
# 156492  🇨🇳's Foreign Minister Wang Yi has also said th...
# 156494  Repeat after me, Canadians are polite, they wo...
#
#                                                  hashtags  \
# 1       ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...
# 2                                                     NaN
# 3                                                     NaN
# 5                             ['COVID19', 'COVID19India']
# 14         ['CovidVaccine', 'ChinaVirus', 'COVID19India']
# ...                                                   ...
# 156481                                          ['Japan']
# 156486                                                NaN
# 156490                                                NaN
# 156492                                                NaN
# 156494                                        ['Trudeau']
#
#                      source is_retweet
# 1       Twitter for Android      False
# 2           Twitter Web App      False
# 3       Twitter for Android      False
# 5       Twitter for Android      False
# 14          Twitter Web App      False
# ...                     ...        ...
# 156481      Twitter Web App      False
# 156486      Twitter Web App      False
# 156490      Twitter Web App      False
# 156492      Twitter Web App      False
# 156494      Twitter Web App      False
#
# [31858 rows x 13 columns]

# %%
tweet_data['user_location'].unique
# Out:
# <bound method Series.unique of 0                             Assam
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4         Adelaide, South Australia
#                     ...
# 156491                  Doha, Qatar
# 156492                          NaN
# 156493                           UK
# 156494                          NaN
# 156495                     Pakistan
# Name: user_location, Length: 156492, dtype: object>

# %%
tweet_data['user_location'].value_counts()
# Out:
# India                             2732
# United States                     2213
# London, England                   2207
# London                            1908
# United Kingdom                    1338
#                                   ...
# God’s Own County of Dorset           1
# North Wales, United Kingdom          1
# Centurion, Pretoria, S Africa        1
# American in Munich, Germany :)       1
# Hammond, La                          1
# Name: user_location, Length: 22226, dtype: int64

# %%
print(len(set(tweet_data["user_location"])))
print(set(tweet_data["user_location"]))
# Out:
# 22227
# {nan, 'Weirton, WV', "Newton's Tree", 'Banbridge, Northern Ireland', 'Somewhere in the Midwest', '19 Sutter Street San Francisco', 'student loan debt', 'Kill Devil Hills, NC', 'Caernarfon | 🚇 London ', 'Winnipeg, Manitoba, CANADA', 'where ever...', 'Rosemont, IL', 'Grandview Heights, OH', 'East Lansing, MI', 'Make Money Get Wealthy ', 'Michigan, USA', 'Limerick city kid, Ireland', 'Guadalajara, MX', '@
-on-Wye, Herefordshire', 'Lostock Hall', 'Telford via North Belfast', 'Shenzhen, China', 'BRD medical college ,Gorakhpur', "Lee's Summit, MO USA", 'Mangaluru/Bengaluru', 'Worli, Mumbai', 'Düsseldorf, Essen', "N 52°15' 0'' / W 1°31' 0''", 'Deana Hendrickson, Los Angeles', 'Cloud based. ', 'Great Britain', 'Stuttgart, Germany', 'Chittagong, Bangladesh', 'Davangere/Chitradurga, India', 'Tempe, AZ & Door County, WI', 'Lake Mills, Iowa', 'Gent', 'Starship Enterprise', 'Coming to an Airport near you', 'Winterfell', 'West Michigan ', 'Toronto, ON / Vadodara, GJ', 'nunya ', 'Mugu, Nepal Himalaya', 'Everywhere You Are ', 'Tulsa Oklahoma', 'Malaga, Spain', 'Ernakulam', 'NW England', 'Poole, Dorset', 'Brixton, England', 'NEOhio', 'Gothenburg, Sweden', 'right where i want to be', 'Birmingham, London', 'Port Douglas - Queensland', 'Beaverton, Oregon, USA', 'Foley, AL', 'Doom Kingdom', 'Buncombe County, NC', 'Muscle Shoals, AL', 'Stage door', 'The West of Ireland', 'Ljubljana, Slovenia', 'सिलीगुड़ी, भारत', 'Brighton, United Kingdom', 'Neasden, Lond ...

# %%
tweet_data[tweet_data['user_location'] == '...']
# Out:
#            user_name user_location  \
# 25785            CRD           ...
# 139334  gaius odiase           ...
# 155217           CRD           ...
#
#                                          user_description  \
# 25785   Poet/Pianist/Politics/Art& #BB Commentary Wome...
# 139334                                                NaN
# 155217  Poet/Pianist/Politics/Art& #BB Commentary Wome...
#
#                user_created  user_followers user_friends user_favourites  \
# 25785   2009-08-27 02:30:28          4290.0       4631.0         54263.0
# 139334  2014-12-22 21:55:46          3116.0         2920             839
# 155217  2009-08-27 02:30:28          4293.0         4336           55569
#
#        user_verified                 date  \
# 25785          False  2020-12-31 00:32:15
# 139334         False  2021-02-24 17:49:19
# 155217         False  2021-03-04 19:51:57
#
#                                                      text          hashtags  \
# 25785   Of course. This country under #Trump,  and his...         ['Trump']
# 139334   but why is 🇬🇭 getting #covidvaccine before 🇳🇬..?  ['covidvaccine']
# 155217  Really seems like some Republican Govs R tryin...               NaN
#
#                      source is_retweet
# 25785      Twitter for iPad      False
# 139334  Twitter for Android      False
# 155217  Twitter for Android      False

# %%
tweet_data.shape
# Out:
# (156492, 13)

# %%
tweet_data['text']
# Out:
# 0         Australia to Manufacture Covid-19 Vaccine and ...
# 1         #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2         Deaths due to COVID-19 in Affected Countries\n...
# 3         @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4         @michellegrattan @ConversationEDU This is what...
#                                 ...
# 156491    Very good news about the efficacy of the J&amp...
# 156492    🇨🇳's Foreign Minister Wang Yi has also said th...
# 156493    Super excited to have received my second #covi...
# 156494    Repeat after me, Canadians are polite, they wo...
# 156495    Instead of postponing psl why not vaccinate al...
# Name: text, Length: 156492, dtype: object
